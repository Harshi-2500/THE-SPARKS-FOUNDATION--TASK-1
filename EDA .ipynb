# %% [markdown]
# # THE SPARKS FOUNDATION INTERNSHIP

# %% [markdown]
# # TASK 1:EXPLORATORY DATA ANALYSIS ON GLOBAL TERRORISM

# %% [markdown]
# # NAME: K.HARSHITHA

# %%
#IMPORTING THE REQUIRED LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IMPORTING THE DATASET
df=pd.read_csv("C:\Harshitha\Global Terrorism.csv",encoding='latin',low_memory=False)
print("Dataset Imported successfully!")
# Out:
# Dataset Imported successfully!

# %%
#DISPLAYING THE CONTENTS OF THE FIRST 5 ROWS
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#DISPLAYING THE CONTENTS OF THE LAST 5 ROWS
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002705  0.018270  0.091762 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002705  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018270  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091762  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077851 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175606 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
#PLOTTING ATTACKING METHODS BY TERRORISTS
plt.figure(figsize=(10,5))
sns.countplot(df['attacktype1_txt'])
plt.xticks(rotation=90)
plt.title('ATTACKING METHODS BY TERRORISTS')
plt.xlabel('ATTACK TYPES')
plt.ylabel('ATTACKS')
plt.show()

# %%
#PLOTTING FAVOURITE TARGETS
plt.figure(figsize=(20,10))
sns.countplot(df['targtype1_txt'])
plt.xticks(rotation=90)
plt.title('FAVOURITE TARGETS')
plt.xlabel('TARGET TYPE')
plt.ylabel('TARGET')
plt.show()

# %%
#PLOTTING COUNTRIES ATTACKED
plt.figure(figsize=(20,8))
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.title('COUNTRIES ATTACKED')
plt.xticks(rotation=40)
plt.xlabel('COUNTRY')
plt.ylabel('ATTACKS')
plt.show()

# %%
#PLOTTING NO.OF ATTACKS PER YEAR
plt.figure(figsize=(12,8))
sns.countplot(df['iyear'])
plt.title('NUMBER OF ATTACKS PER YEAR')
plt.xticks(rotation=60)
plt.xlabel('YEAR')
plt.ylabel('NO.OF ATTACKS')
plt.show()

# %%
#PLOTTING NUMBER OF ATTACKS IN EACH CITY
plt.figure(figsize=(20,10))
sns.barplot(x=df['city'].value_counts()[:20].index,y=df['city'].value_counts()[:20].values)
plt.title('NUMBER OF ATTACKS IN EACH CITY')
plt.xticks(rotation=40)
plt.xlabel('CITIES')
plt.ylabel('NO.OF ATTACKS')
plt.show()

# %%
#PLOTTING TERRORIST ACTIVITIES IN EACH REGION
plt.figure(figsize=(15,5))
sns.countplot(df['region_txt'])
plt.title('TERRORIST ACTIVITIES IN EACH REGION')
plt.xticks(rotation=75)
plt.xlabel('REGIONS')
plt.ylabel('NO.OF ATTACKS')
plt.show()

# %%
#PLOTTING FREQUENCY OF WEAPONS USED
x=df['weaptype1_txt'].value_counts()[:10].index
y=df['weaptype1_txt'].value_counts()[:10].values
sns.barplot(x,y)
plt.title('FREQUENCY OF WEAPONS USED')
plt.xlabel('WEAPONS USED')
plt.ylabel('FREQUENCY')
plt.xticks(rotation=90)
plt.show()

# %%
#NUMBER OF FATALITIES PER YEAR
x=df['iyear']
y=df['nkill']
plt.scatter(x,y)
plt.title('NUMBER OF FATALITIES PER YEAR')
plt.xlabel('YEAR')
plt.ylabel('NUMBER OF FATALITIES')
plt.show()

# %% [markdown]
# # OBSERVATIONS:
#     1. BOMBING/EXPLOSION were the most common attacking methods used by terrorists followed by ARMED ASSAULTS, ASSANSINATION
#         and so on. Attacks caused by BOMBING/EXPLOSION was almost twice than the next most attack which was ARMED ASSAULT.
#     2. CITIZENS, MILITARY, GOVERNMENT and POLICE were the most common target types.
#     3. IRAQ and PAKISTAN were the most attacked countries followed by AFGHANISTAN, INDIA, COLUMBIA and so on.
#     4. Terrorist attacks were quite low in numbers in the decade of 1970 and then had a rise in the 1980s and early 1990s.
#        But there was a huge growth in terrorist attacks from 2000 to 2014.
#     5. UNKNOWN and BAGHDAD were the most attacked cities while GAUTEMALA CITY and BAQUBAH were the least attacked cities.
#     6. MIDDLE EAST & NORTH AFRICA and SOUTH ASIA were the most attacked regions followed SOUTH AMERICA, SUB-SAHARAN AFRICA,
#        WESTERN EUROPE and so on.
#     7. EXPLOSIVES and FIREARMS were the most used weapons.
